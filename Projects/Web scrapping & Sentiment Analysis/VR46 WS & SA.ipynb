# %% [markdown]
# # Web scraping and sentiment analysis

# %%
#Scraping article1
import requests
from bs4 import BeautifulSoup

# %%
vr='https://www.motorsportmagazine.com/archive/article/august-2015/47/making-valentino-rossi'
link=requests.get(vr).text

# %%
soup=BeautifulSoup(link,'lxml')

# %%
sp=soup.prettify()

# %%
soup.title.string
# Out:
# 'The making of Valentino Rossi | Motor Sport Magazine Archive'

# %%
soup.a
# Out:
# <a href="/" title="">Motor Sport home</a>

# %%
#links
all_link=soup.find_all('a')
for link in all_link:
    link.get('href')

# %%
result=soup.find('div',{'class':'field field-name-field-body-text field-type-text-long field-label-hidden'})
print(result)
# Out:
# <div class="field field-name-field-body-text field-type-text-long field-label-hidden">
# <div class="field-items">
# <div class="field-item even"><p><strong>Mat Oxley</strong></p>
# <p>On August 18 1996 <a href="/node/185002">Valentino Rossi</a> won his first Grand Prix, in the 125cc class at <a href="/node/197517">Brno</a> in the Czech Republic. Eighteen years later he is still winning Grands Prix. You probably already know that this is a unique achievement in motorcycle racing.</p>
# <p class="article-img-full-width"><img alt="Valentino Rossi racing at 2008 Potuguese MotoGP Estoril" src="/sites/default/files/content/2008%20Portuguese%20MotoGP/rossi_2008_motogp_portugal_estoril.jpg" style="width: 100%;"/></p>
# <p>That first victory wasn’t followed by theatrical celebrations or frenzied crowd worship, because the Rossi legend had yet to be built. In the summer of 1996 no one knew that the 16-year-old would amount to anything special because success in GP racing’s smallest class is no guarantee. The bike world is littered with the broken bikes, bones and dreams of successful juniors who thought they had what it takes. But handling 50bhp doesn’t mean you will cope with 250 and enough electronics to send you to the moon.</p>
# <p>When Rossi commenced his GP career that spring, he wasn’t even sure he had what it takes to make it in 125s. The first time he shared a track with 125 GP riders he was stunned by their speed.<!-- /22623031/MSMag_ROS_RHS_1 --></p><div class="inline-body-ad" id="div-gpt-ad-1489396684985-9"></div>
# <p>“F**k, it was incredible!” he says. “They were so fast! It was like another sport, maybe four seconds a lap faster. I needed to learn another way to ride.”</p>
# <p>School friend Uccio Salucci – still at Rossi’s side – remembers the sense of foreboding that came over the youngster during his baptism.</p>
# <p>“After a few days testing Valentino said, ‘F**k, Uccio, these riders are very, very fast; maybe too fast for me’.”</p>
# <p>Rossi wasn’t a particularly quick learner in his younger days. He had yet to locate the limit and spent most of 1996 tripping right over it, much to the disgust of team owner Giampiero Sacchi, who was paying for the accident damage to Rossi’s <a href="/node/190408">Aprilia</a> RS125.</p>
# <p class="article-img-full-width"><img alt="Valentino Rossi greets fans on podium at 2008 Mugello MotoGP Italy" src="/sites/default/files/content/2008%20MotoGP%20Mugello/rossi_2008_motogp_italy_mugello.jpg" style="width: 100%;"/></p>
# <p><strong>Rossi greets fans from the podium after the 2008 Mugello MotoGP</strong> <em>Photo: Motorsport Images</em></p>
# <p>“Many of these crashes came from Vale [pronounced as in ‘valley’] not thinking: the tyres, cold... give gas... crash!” says Sacchi, rolling his eyes. “So we take him into the motorhome and I say, ‘Vale, how is it possible you crash so much?’ But now I understand: if a young rider is very fast, he’s going to crash. He needs to discover the limit, and without crashing that’s impossible.”</p>
# 'Rossi: Yamaha "stronger than last year" despite Jerez letdown'

# %%
soup1.a
# Out:
# <a class="ms-dropdown_link" data-series="all" href="#">Top events</a>

# %%
#links
all_link=soup1.find_all('a')
for link1 in all_link:
    link1.get('href')

# %%
result1=soup1.find('div',{'ms-article-content-wrapper ms-mtb'})
print(result1)
# Out:
# <div class="ms-article-content-wrapper ms-mtb"> <div class="ms-article-content"> <p>Having featured firmly in the podium hunt in the first three races of the season, Rossi could do no better than sixth from 13th on the grid at Jerez, a track that has exposed the M1's bike weaknesses in recent years.</p><div class="ms-ap-native"><div class="ms-ap" data-dfp-attrs='{"ms_native":"1","msnt_env":"production","ms_category":"all","ms_series":"motogp","ms_page_type":"detail","ms_page_content_type":"article","ms_page_content_id":"4382503","ms_banner_name":"native","ms_edition":"global","ms_lang":"en","ms_event_id":"261330","ms_subevent_id":"754306","ms_author_id":"15103","ms_location_id":"15103","ms_drivers":["770"],"ms_teams":["537"],"ms_banner_position":"native"}' data-dfp-code="MST/global/Native" data-height="1" data-id="20" data-sizes="fluid,1x1" data-width="1"></div></div> <p>But the result did not knock Rossi's confidence about his prospects for the year, although he did reiterate Honda rider Marc Marquez's current imperious form is a worry for the title race.</p> <p>“We are stronger than last year," said the Italian. "The way is long, the challenge is very high, but we work in a good direction. I'm not fully happy for sure because I hoped that also in Jerez, that is a difficult track, we could fight for the podium, but at the end I was a bit more slow.</p><div class="ms-ap-native"><div class="ms-ap" data-dfp-attrs='{"ms_native":"2","msnt_env":"production","ms_category":"all","ms_series":"motogp","ms_page_type":"detail","ms_page_content_type":"article","ms_page_content_id":"4382503","ms_banner_name":"native","ms_edition":"global","ms_lang":"en","ms_event_id":"261330","ms_subevent_id":"754306","ms_author_id":"15103","ms_location_id":"15103","ms_drivers":["770"],"ms_teams":["537"],"ms_banner_position":"native"}' data-dfp-code="MST/global/Native" data-height="1" data-id="20" data-sizes="fluid,1x1" data-width="1"></div></div> <p>“But for me we can fight. I'm not so far in the championship, the bigger problem in the championship is Marquez, because he's clearly the faster. So if he don't crash in Austin, already the difference is big.</p> <p>“But we are there, we are nine points behind, also [Alex] Rins is very strong, also [Andrea] Dovi[zioso], but looks like we can fight for try to make some podiums and try to win some races.”</p> <p>Rossi was left wondering whether he should've copied his podium-finishing teammate Maverick Vinales' choice of the medium front tyre instead of running the hard – but also believed that missing out on Q2 made his weekend “more difficult”.</p> <p>“I was never very strong during all the weekend, at the beginning I struggle with [Jack] Miller, but because I was not strong enough to overtake," he admitted.</p> <p>“Maybe if I go straight to the Q2 I can start in the second or third row, and if I start more in front, I can stay for me with the group of the two Ducati and Maverick, around them.”</p><div class="ms-apb ms-apb-inarticle-after-preview-without-sidebar"><div class="ms-ap" data-dfp-attrs='{"msnt_env":"production","ms_category":"all","ms_series":"motogp","ms_page_type":"detail","ms_page_content_type":"article","ms_page_content_id":"4382503","ms_banner_name":"inarticle-after-preview-without-sidebar","ms_edition":"global","ms_lang":"en","ms_event_id":"261330","ms_subevent_id":"754306","ms_author_id":"15103","ms_location_id":"15103","ms_drivers":["770"],"ms_teams":["537"],"ms_banner_position":"inarticle-after-preview-without-sidebar"}' data-dfp-code="MST/global/DMPU" data-height="250" data-id="3" data-sizes="300x250,300x600" data-width="300" style="width:300px;min-height:250px;"></div></div> <p>Though Rossi finished a place higher at Jerez in 2018, this was aided by a three-bike crash involving Dovizioso, Jorge Lorenzo and Dani Pedrosa, and Rossi insisted his 2019 showing was stronger.</p> <p>“I don't know what we had to expect here in Jerez, I hoped in my heart to be strong like in Austin, for example, u ...

# %%
v1=result1.get_text()
print(v1)
# Out:
#   Having featured firmly in the podium hunt in the first three races of the season, Rossi could do no better than sixth from 13th on the grid at Jerez, a track that has exposed the M1's bike weaknesses in recent years. But the result did not knock Rossi's confidence about his prospects for the year, although he did reiterate Honda rider Marc Marquez's current imperious form is a worry for the title race. “We are stronger than last year," said the Italian. "The way is long, the challenge is very high, but we work in a good direction. I'm not fully happy for sure because I hoped that also in Jerez, that is a difficult track, we could fight for the podium, but at the end I was a bit more slow. “But for me we can fight. I'm not so far in the championship, the bigger problem in the championship is Marquez, because he's clearly the faster. So if he don't crash in Austin, already the difference is big. “But we are there, we are nine points behind, also [Alex] Rins is very strong, also [Andrea] Dovi[zioso], but looks like we can fight for try to make some podiums and try to win some races.” Rossi was left wondering whether he should've copied his podium-finishing teammate Maverick Vinales' choice of the medium front tyre instead of running the hard – but also believed that missing out on Q2 made his weekend “more difficult”. “I was never very strong during all the weekend, at the beginning I struggle with [Jack] Miller, but because I was not strong enough to overtake," he admitted. “Maybe if I go straight to the Q2 I can start in the second or third row, and if I start more in front, I can stay for me with the group of the two Ducati and Maverick, around them.” Though Rossi finished a place higher at Jerez in 2018, this was aided by a three-bike crash involving Dovizioso, Jorge Lorenzo and Dani Pedrosa, and Rossi insisted his 2019 showing was stronger. “I don't know what we had to expect here in Jerez, I hoped in my heart to be strong like in Austin, for example, unfortunately we struggle a bit more, I was less fast," he said. “But we have also a lot of good things because also if my position is worse than last year, my race was a lot better. “Last year I finished fifth but because I have a lot of crashes in front. And the pace of the race [this year] was very, very, very fast, I was like 25 seconds [actually 32 seconds] faster than my race last year, the gap from the first position is less. "I feel more comfortable with the bike and especially in the last laps I was fast.” Additional reporting by Oriol Puigdemont

# %%
#cleaning and preprocessing article1 
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
v_token=word_tokenize(v)
print(v_token)
# Out:
# ['Mat', 'Oxley', 'On', 'August', '18', '1996', 'Valentino', 'Rossi', 'won', 'his', 'first', 'Grand', 'Prix', ',', 'in', 'the', '125cc', 'class', 'at', 'Brno', 'in', 'the', 'Czech', 'Republic', '.', 'Eighteen', 'years', 'later', 'he', 'is', 'still', 'winning', 'Grands', 'Prix', '.', 'You', 'probably', 'already', 'know', 'that', 'this', 'is', 'a', 'unique', 'achievement', 'in', 'motorcycle', 'racing', '.', 'That', 'first', 'victory', 'wasn', '’', 't', 'followed', 'by', 'theatrical', 'celebrations', 'or', 'frenzied', 'crowd', 'worship', ',', 'because', 'the', 'Rossi', 'legend', 'had', 'yet', 'to', 'be', 'built', '.', 'In', 'the', 'summer', 'of', '1996', 'no', 'one', 'knew', 'that', 'the', '16-year-old', 'would', 'amount', 'to', 'anything', 'special', 'because', 'success', 'in', 'GP', 'racing', '’', 's', 'smallest', 'class', 'is', 'no', 'guarantee', '.', 'The', 'bike', 'world', 'is', 'littered', 'with', 'the', 'broken', 'bikes', ',', 'bones', 'and', 'dreams', 'of', 'successful', 'juniors', 'who', 'thought', 'they', 'had', 'what', 'it', 'takes', '.', 'But', 'handling', '50bhp', 'doesn', '’', 't', 'mean', 'you', 'will', 'cope', 'with', '250', 'and', 'enough', 'electronics', 'to', 'send', 'you', 'to', 'the', 'moon', '.', 'When', 'Rossi', 'commenced', 'his', 'GP', 'career', 'that', 'spring', ',', 'he', 'wasn', '’', 't', 'even', 'sure', 'he', 'had', 'what', 'it', 'takes', 'to', 'make', 'it', 'in', '125s', '.', 'The', 'first', 'time', 'he', 'shared', 'a', 'track', 'with', '125', 'GP', 'riders', 'he', 'was', 'stunned', 'by', 'their', 'speed', '.', '“', 'F**k', ',', 'it', 'was', 'incredible', '!', '”', 'he', 'says', '.', '“', 'They', 'were', 'so', 'fast', '!', 'It', 'was', 'like', 'another', 'sport', ',', 'maybe', 'four', 'seconds', 'a', 'lap', 'faster', '.', 'I', 'needed', 'to', 'learn', 'another', 'way', 'to', 'ride.', '”', 'School', 'friend', 'Uccio', 'Salucci', '–', 'still', 'at', 'Rossi', '’', 's', 'side', '–', 'remembers', 'the', 'sense', 'of', 'foreboding', 'that', 'came', 'over', 'the', 'youngster', 'during', 'his', 'baptism', '.', '“', 'After', 'a', 'few', 'days', 'testing', 'Valentino', 'said', ',', '‘', 'F**k', ',', 'Uccio', ',', 'these', 'riders', 'are', 'very', ',', 'very', 'fast', ';', 'maybe', 'too', 'fast', 'for', 'me', '’', '.', '”', 'Rossi', 'wasn', '’', 't', 'a', 'particularly', 'quick', 'learner', 'in', 'his', 'younger', 'days', '.', 'He', 'had', 'yet', 'to', 'locate', 'the', 'limit', 'and', 'spent', 'most', 'of', '1996', 'tripping', 'right', 'over', 'it', ',', 'much', 'to', 'the', 'disgust', 'of', 'team', 'owner', 'Giampiero', 'Sacchi', ',', 'who', 'was', 'paying', 'for', 'the', 'accident', 'damage', 'to', 'Rossi', '’', 's', 'Aprilia', 'RS125', '.', 'Rossi', 'greets', 'fans', 'from', 'the', 'podium', 'after', 'the', '2008', 'Mugello', 'MotoGP', 'Photo', ':', 'Motorsport', 'Images', '“', 'Many', 'of', 'these', 'crashes', 'came', 'from', 'Vale', '[', 'pronounced', 'as', 'in', '‘', 'valley', '’', ']', 'not', 'thinking', ':', 'the', 'tyres', ',', 'cold', '...', 'give', 'gas', '...', 'crash', '!', '”', 'says', 'Sacchi', ',', 'rolling', 'his', 'eyes', '.', '“', 'So', 'we', 'take', 'him', 'into', 'the', 'motorhome', 'and', 'I', 'say', ',', '‘', 'Vale', ',', 'how', 'is', 'it', 'possible', 'you', 'crash', 'so', 'much', '?', '’', 'But', 'now', 'I', 'understand', ':', 'if', 'a', 'young', 'rider', 'is', 'very', 'fast', ',', 'he', '’', 's', 'going', 'to', 'crash', '.', 'He', 'needs', 'to', 'discover', 'the', 'limit', ',', 'and', 'without', 'crashing', 'that', '’', 's', 'impossible.', '”', 'Rossi', 'wasn', '’', 't', 'the', 'only', 'one', 'getting', 'lost', 'and', 'ending', 'up', 'tumbling', 'down', 'the', 'road', 'chased', 'by', 'a', 'disintegrating', 'motorcycle', '.', 'At', 'that', 'time', 'the', '125', 'class', 'was', 'changing', ',', 'with', 'a', 'new', 'breed', 'of', 'youngsters', 'prepared', 'to', 'win', 'by', 'any', 'means', 'necessary', ',', 'regardless', 'of', 'whether', 'that', 'meant', 'knocking', 'off', 'a', 'rival', 'o ...

# %%
len(v_token)
# Out:
# 1090

# %%
#Frequency of words
from nltk.probability import FreqDist
fdist=FreqDist()

# %%
for word in v_token:
    fdist[word.lower()]+=1
fdist
# Out:
# FreqDist({',': 50, 'the': 43, '.': 42, 'to': 27, '’': 23, 'in': 19, 'he': 18, 'a': 17, 'and': 16, 'was': 16, ...})

# %%
fdist_top=fdist.most_common(15)
fdist_top
# Out:
# [(',', 50),
#  ('the', 43),
#  ('.', 42),
#  ('to', 27),
#  ('’', 23),
#  ('in', 19),
#  ('he', 18),
#  ('a', 17),
#  ('and', 16),
#  ('was', 16),
#  ('of', 15),
#  ('i', 15),
#  ('rossi', 14),
#  ('his', 13),
#  ('that', 13)]

# %%
#no of paragraphs
from nltk.tokenize import blankline_tokenize
v_bt=blankline_tokenize(v)
len(v_bt)
# Out:
# 4

# %%
#from nltk.util import bigrams,trigrams,ngrams

# %%
#v_bg=list(nltk.bigrams(v_token))
#v_bg

# %%
#v_tg=list(nltk.trigrams(v_token))
#v_tg

# %%
#v_ng=list(nltk.ngrams(v_token,5))
#v_ng

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()

# %%
v_stem=ps.stem(v)

# %%
v_sc=re.sub('[^a-zA-Z.]',' ',v_stem)
print(v_sc)
# Out:
#   mat oxley on august         valentino rossi won his first grand prix  in the    cc class at brno in the czech republic. eighteen years later he is still winning grands prix. you probably already know that this is a unique achievement in motorcycle racing.  that first victory wasn t followed by theatrical celebrations or frenzied crowd worship  because the rossi legend had yet to be built. in the summer of      no one knew that the    year old would amount to anything special because success in gp racing s smallest class is no guarantee. the bike world is littered with the broken bikes  bones and dreams of successful juniors who thought they had what it takes. but handling   bhp doesn t mean you will cope with     and enough electronics to send you to the moon. when rossi commenced his gp career that spring  he wasn t even sure he had what it takes to make it in    s. the first time he shared a track with     gp riders he was stunned by their speed.  f  k  it was incredible   he says.  they were so fast  it was like another sport  maybe four seconds a lap faster. i needed to learn another way to ride.  school friend uccio salucci   still at rossi s side   remembers the sense of foreboding that came over the youngster during his baptism.  after a few days testing valentino said   f  k  uccio  these riders are very  very fast  maybe too fast for me .  rossi wasn t a particularly quick learner in his younger days. he had yet to locate the limit and spent most of      tripping right over it  much to the disgust of team owner giampiero sacchi  who was paying for the accident damage to rossi s aprilia rs   .  rossi greets fans from the podium after the      mugello motogp photo  motorsport images  many of these crashes came from vale  pronounced as in  valley   not thinking  the tyres  cold... give gas... crash   says sacchi  rolling his eyes.  so we take him into the motorhome and i say   vale  how is it possible you crash so much   but now i understand  if a young rider is very fast  he s going to crash. he needs to discover the limit  and without crashing that s impossible.  rossi wasn t the only one getting lost and ending up tumbling down the road chased by a disintegrating motorcycle. at that time the     class was changing  with a new breed of youngsters prepared to win by any means necessary  regardless of whether that meant knocking off a rival or two. these impetuous upstarts were upsetting the old guard  men like four time world champion jorge martinez  now owner of the aspar motogp team.  now i


# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt 
import pandas as pd

# %%
wc=WordCloud(width=800,height=800,background_color='white',min_font_size=10).generate(v_sw)

# %%
#ploting the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wc) 
plt.axis("off") 
plt.tight_layout(pad = 0)
plt.show()

# %%
#SENTIMENT ANALYZER
from nltk.sentiment.vader import SentimentIntensityAnalyzer
         
sia = SentimentIntensityAnalyzer()
ss = sia.polarity_scores(v_sw)
print(ss)
# Out:
# {'neg': 0.113, 'neu': 0.704, 'pos': 0.183, 'compound': 0.9904}

# %%
if ss["compound"]>=0.5:
    print("positive")
elif ss["compound"]<=-0.5:
    print("negative")
else:
    print("neutral")
# Out:
# positive

# %%
#sSentiment percentage in pie chart
labels=['negative','neutral','positive']
sizes=[ss['neg'],ss['neu'],ss['pos']]
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
#cleaning and preprocessing article2
v_token1=word_tokenize(v1)
print(v_token1)
# Out:
# ['Having', 'featured', 'firmly', 'in', 'the', 'podium', 'hunt', 'in', 'the', 'first', 'three', 'races', 'of', 'the', 'season', ',', 'Rossi', 'could', 'do', 'no', 'better', 'than', 'sixth', 'from', '13th', 'on', 'the', 'grid', 'at', 'Jerez', ',', 'a', 'track', 'that', 'has', 'exposed', 'the', 'M1', "'s", 'bike', 'weaknesses', 'in', 'recent', 'years', '.', 'But', 'the', 'result', 'did', 'not', 'knock', 'Rossi', "'s", 'confidence', 'about', 'his', 'prospects', 'for', 'the', 'year', ',', 'although', 'he', 'did', 'reiterate', 'Honda', 'rider', 'Marc', 'Marquez', "'s", 'current', 'imperious', 'form', 'is', 'a', 'worry', 'for', 'the', 'title', 'race', '.', '“', 'We', 'are', 'stronger', 'than', 'last', 'year', ',', "''", 'said', 'the', 'Italian', '.', '``', 'The', 'way', 'is', 'long', ',', 'the', 'challenge', 'is', 'very', 'high', ',', 'but', 'we', 'work', 'in', 'a', 'good', 'direction', '.', 'I', "'m", 'not', 'fully', 'happy', 'for', 'sure', 'because', 'I', 'hoped', 'that', 'also', 'in', 'Jerez', ',', 'that', 'is', 'a', 'difficult', 'track', ',', 'we', 'could', 'fight', 'for', 'the', 'podium', ',', 'but', 'at', 'the', 'end', 'I', 'was', 'a', 'bit', 'more', 'slow', '.', '“', 'But', 'for', 'me', 'we', 'can', 'fight', '.', 'I', "'m", 'not', 'so', 'far', 'in', 'the', 'championship', ',', 'the', 'bigger', 'problem', 'in', 'the', 'championship', 'is', 'Marquez', ',', 'because', 'he', "'s", 'clearly', 'the', 'faster', '.', 'So', 'if', 'he', 'do', "n't", 'crash', 'in', 'Austin', ',', 'already', 'the', 'difference', 'is', 'big', '.', '“', 'But', 'we', 'are', 'there', ',', 'we', 'are', 'nine', 'points', 'behind', ',', 'also', '[', 'Alex', ']', 'Rins', 'is', 'very', 'strong', ',', 'also', '[', 'Andrea', ']', 'Dovi', '[', 'zioso', ']', ',', 'but', 'looks', 'like', 'we', 'can', 'fight', 'for', 'try', 'to', 'make', 'some', 'podiums', 'and', 'try', 'to', 'win', 'some', 'races.', '”', 'Rossi', 'was', 'left', 'wondering', 'whether', 'he', 'should', "'ve", 'copied', 'his', 'podium-finishing', 'teammate', 'Maverick', 'Vinales', "'", 'choice', 'of', 'the', 'medium', 'front', 'tyre', 'instead', 'of', 'running', 'the', 'hard', '–', 'but', 'also', 'believed', 'that', 'missing', 'out', 'on', 'Q2', 'made', 'his', 'weekend', '“', 'more', 'difficult', '”', '.', '“', 'I', 'was', 'never', 'very', 'strong', 'during', 'all', 'the', 'weekend', ',', 'at', 'the', 'beginning', 'I', 'struggle', 'with', '[', 'Jack', ']', 'Miller', ',', 'but', 'because', 'I', 'was', 'not', 'strong', 'enough', 'to', 'overtake', ',', "''", 'he', 'admitted', '.', '“', 'Maybe', 'if', 'I', 'go', 'straight', 'to', 'the', 'Q2', 'I', 'can', 'start', 'in', 'the', 'second', 'or', 'third', 'row', ',', 'and', 'if', 'I', 'start', 'more', 'in', 'front', ',', 'I', 'can', 'stay', 'for', 'me', 'with', 'the', 'group', 'of', 'the', 'two', 'Ducati', 'and', 'Maverick', ',', 'around', 'them.', '”', 'Though', 'Rossi', 'finished', 'a', 'place', 'higher', 'at', 'Jerez', 'in', '2018', ',', 'this', 'was', 'aided', 'by', 'a', 'three-bike', 'crash', 'involving', 'Dovizioso', ',', 'Jorge', 'Lorenzo', 'and', 'Dani', 'Pedrosa', ',', 'and', 'Rossi', 'insisted', 'his', '2019', 'showing', 'was', 'stronger', '.', '“', 'I', 'do', "n't", 'know', 'what', 'we', 'had', 'to', 'expect', 'here', 'in', 'Jerez', ',', 'I', 'hoped', 'in', 'my', 'heart', 'to', 'be', 'strong', 'like', 'in', 'Austin', ',', 'for', 'example', ',', 'unfortunately', 'we', 'struggle', 'a', 'bit', 'more', ',', 'I', 'was', 'less', 'fast', ',', "''", 'he', 'said', '.', '“', 'But', 'we', 'have', 'also', 'a', 'lot', 'of', 'good', 'things', 'because', 'also', 'if', 'my', 'position', 'is', 'worse', 'than', 'last', 'year', ',', 'my', 'race', 'was', 'a', 'lot', 'better', '.', '“', 'Last', 'year', 'I', 'finished', 'fifth', 'but', 'because', 'I', 'have', 'a', 'lot', 'of', 'crashes', 'in', 'front', '.', 'And', 'the', 'pace', 'of', 'the', 'race', '[', 'this', 'year', ']', 'was', 'very', ',', 'very', ',', 'very', 'fast', ',', 'I', 'was', 'like', '25', 'seconds', '[', 'actu ...

# %%
len(v_token1)
# Out:
# 567

# %%
for word in v_token1:
    fdist[word.lower()]+=1
fdist
# Out:
# FreqDist({',': 85, 'the': 75, '.': 57, 'in': 35, 'i': 34, 'to': 33, 'a': 28, 'was': 27, 'he': 24, '’': 23, ...})

# %%
fdist_top1=fdist.most_common(15)
fdist_top1
# Out:
# [(',', 85),
#  ('the', 75),
#  ('.', 57),
#  ('in', 35),
#  ('i', 34),
#  ('to', 33),
#  ('a', 28),
#  ('was', 27),
#  ('he', 24),
#  ('’', 23),
#  ('and', 23),
#  ('of', 22),
#  ('rossi', 19),
#  ('is', 19),
#  ('“', 19)]

# %%
#no of paragraphs
v_bt1=blankline_tokenize(v1)
len(v_bt1)
# Out:
# 1

# %%
v_stem1=ps.stem(v1)

# %%
v_sc1=re.sub('[^a-zA-Z]',' ',v_stem1)
print(v_sc1)
# Out:
#   having featured firmly in the podium hunt in the first three races of the season  rossi could do no better than sixth from   th on the grid at jerez  a track that has exposed the m  s bike weaknesses in recent years  but the result did not knock rossi s confidence about his prospects for the year  although he did reiterate honda rider marc marquez s current imperious form is a worry for the title race   we are stronger than last year   said the italian   the way is long  the challenge is very high  but we work in a good direction  i m not fully happy for sure because i hoped that also in jerez  that is a difficult track  we could fight for the podium  but at the end i was a bit more slow   but for me we can fight  i m not so far in the championship  the bigger problem in the championship is marquez  because he s clearly the faster  so if he don t crash in austin  already the difference is big   but we are there  we are nine points behind  also  alex  rins is very strong  also  andrea  dovi zioso   but looks like we can fight for try to make some podiums and try to win some races   rossi was left wondering whether he should ve copied his podium finishing teammate maverick vinales  choice of the medium front tyre instead of running the hard   but also believed that missing out on q  made his weekend  more difficult    i was never very strong during all the weekend  at the beginning i struggle with  jack  miller  but because i was not strong enough to overtake   he admitted   maybe if i go straight to the q  i can start in the second or third row  and if i start more in front  i can stay for me with the group of the two ducati and maverick  around them   though rossi finished a place higher at jerez in       this was aided by a three bike crash involving dovizioso  jorge lorenzo and dani pedrosa  and rossi insisted his      showing was stronger   i don t know what we had to expect here in jerez  i hoped in my heart to be strong like in austin  for example  unfortunately we struggle a bit more  i was less fast   he said   but we have also a lot of good things because also if my position is worse than last year  my race was a lot better   last year i finished fifth but because i have a lot of crashes in front  and the pace of the race  this year  was very  very  very fast  i was like    seconds  actually    seconds  faster than my race last year  the gap from the first position is less   i feel more comfortable with the bike and especially in the last laps i was fast   additional reporting by oriol puigdemont

# %%
v_sw1= ' '.join([word for word in v_sc1.split() if word not in (stopwords.words('english'))])
print(v_sw1)
# Out:
# featured firmly podium hunt first three races season rossi could better sixth th grid jerez track exposed bike weaknesses recent years result knock rossi confidence prospects year although reiterate honda rider marc marquez current imperious form worry title race stronger last year said italian way long challenge high work good direction fully happy sure hoped also jerez difficult track could fight podium end bit slow fight far championship bigger problem championship marquez clearly faster crash austin already difference big nine points behind also alex rins strong also andrea dovi zioso looks like fight try make podiums try win races rossi left wondering whether copied podium finishing teammate maverick vinales choice medium front tyre instead running hard also believed missing q made weekend difficult never strong weekend beginning struggle jack miller strong enough overtake admitted maybe go straight q start second third row start front stay group two ducati maverick around though rossi finished place higher jerez aided three bike crash involving dovizioso jorge lorenzo dani pedrosa rossi insisted showing stronger know expect jerez hoped heart strong like austin example unfortunately struggle bit less fast said also lot good things also position worse last year race lot better last year finished fifth lot crashes front pace race year fast like seconds actually seconds faster race last year gap first position less feel comfortable bike especially last laps fast additional reporting oriol puigdemont

# %%
for token in v_token1:
    pos_tag1=nltk.pos_tag([token])
    #print(pos_tag1)

# %%
#ploting the WordCloud image
wc1=WordCloud(width=800,height=800,background_color='white',min_font_size=10).generate(v_sw1)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wc1) 
plt.axis("off") 
plt.tight_layout(pad = 0)
plt.show()

# %%
#sentiment analyxer
ss1=sia.polarity_scores(v_sw1)
print(ss1)
# Out:
# {'neg': 0.137, 'neu': 0.614, 'pos': 0.249, 'compound': 0.9871}

# %%
if ss1["compound"]>=0.5:
    print("positive")
elif ss1["compound"]<=-0.5:
    print("negative")
else:
    print("neutral")
# Out:
# positive

# %%
#Sentiment percentage in pie chart
labels=['negative','neutral','positive']
sizes=[ss1['neg'],ss1['neu'],ss1['pos']]
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.axis('equal')
plt.show()
